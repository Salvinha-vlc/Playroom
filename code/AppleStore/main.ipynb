# %% [markdown]
# # Pandas Deep-Dive

# %%
import pandas as pd
import numpy as np

# %%
apps = pd.read_csv("../data/appleStore.csv")

# %%
apps.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           0  281656475                                    PAC-MAN Premium
# 1           1  281796108                          Evernote - stay organized
# 2           2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           4  282935706                                              Bible
#
#    size_bytes  price  rating_count_tot  rating_count_ver  user_rating  \
# 0   100788224   3.99             21292                26          4.0
# 1   158578688   0.00            161065                26          4.0
# 2   100524032   0.00            188583              2822          3.5
# 3   128512000   0.00            262241               649          4.0
# 4    92774400   0.00            985920              5320          4.5
#
#     prime_genre
# 0         Games
# 1  Productivity
# 2       Weather
# 3      Shopping
# 4     Reference

# %%
apps.shape
# Out:
# (7197, 9)

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 9 columns):
# Unnamed: 0          7197 non-null int64
# id                  7197 non-null int64
# track_name          7197 non-null object
# size_bytes          7197 non-null int64
# price               7197 non-null float64
# rating_count_tot    7197 non-null int64
# rating_count_ver    7197 non-null int64
# user_rating         7197 non-null float64
# prime_genre         7197 non-null object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 506.1+ KB

# %%
apps.duplicated().sum()
# Out:
# 0

# %%
apps.track_name.nunique()
# Out:
# 7195

# %%
apps[apps.track_name.duplicated(keep=False)]
# Out:
#       Unnamed: 0          id           track_name  size_bytes  price  \
# 3319        3319   952877179    VR Roller Coaster   169523200    0.0
# 5603        5603  1089824278    VR Roller Coaster   240964608    0.0
# 7092        7092  1173990889  Mannequin Challenge   109705216    0.0
# 7128        7128  1178454060  Mannequin Challenge    59572224    0.0
#
#       rating_count_tot  rating_count_ver  user_rating prime_genre
# 3319               107               102          3.5       Games
# 5603                67                44          3.5       Games
# 7092               668                87          3.0       Games
# 7128               105                58          4.0       Games

# %%
apps.drop("Unnamed: 0", axis=1, inplace=True)

# %%
apps.id.duplicated().sum()
# Out:
# 0

# %%
apps.head()
# Out:
#           id                                         track_name  size_bytes  \
# 0  281656475                                    PAC-MAN Premium   100788224
# 1  281796108                          Evernote - stay organized   158578688
# 2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts   100524032
# 3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...   128512000
# 4  282935706                                              Bible    92774400
#
#    price  rating_count_tot  rating_count_ver  user_rating   prime_genre
# 0   3.99             21292                26          4.0         Games
# 1   0.00            161065                26          4.0  Productivity
# 2   0.00            188583              2822          3.5       Weather
# 3   0.00            262241               649          4.0      Shopping
# 4   0.00            985920              5320          4.5     Reference

# %% [markdown]
# ### What is the average rating of all apps?

# %%
apps.user_rating.mean()
# Out:
# 3.526955675976101

# %% [markdown]
# ### How many apps have an average rating no less than 4?

# %% [markdown]
# 1st way

# %%
user_rating_above_4 = apps[apps.user_rating>=4]

# %%
len(user_rating_above_4)
# Out:
# 4781

# %% [markdown]
# 2nd more direct way

# %%
apps[apps.user_rating>=4].id.count()
# Out:
# 4781

# %% [markdown]
# ### How many genres are there in total for all the apps?

# %%
apps.prime_genre.nunique()
# Out:
# 23

# %% [markdown]
# ### What are the top 3 genres that have the most number of apps?

# %%
apps.prime_genre.value_counts().nlargest(3)
# Out:
# Games            3862
# Entertainment     535
# Education         453
# Name: prime_genre, dtype: int64

# %% [markdown]
# ### Which genre is most likely to contain free apps?

# %% [markdown]
# Absolute figures

# %%
free_apps = apps.loc[apps.price == 0, :]

# %%
free_apps.prime_genre.value_counts().to_frame(name="Free apps")
# Out:
#                    Free apps
# Games                   2257
# Entertainment            334
# Photo & Video            167
# Social Networking        143
# Education                132
# Shopping                 121
# Utilities                109
# Lifestyle                 94
# Finance                   84
# Sports                    79
# Health & Fitness          76
# Music                     67
# Book                      66
# Productivity              62
# News                      58
# Travel                    56
# Food & Drink              43
# Weather                   31
# Navigation                20
# Reference                 20
# Business                  20
# Catalogs                   9
# Medical                    8

# %% [markdown]
# ### Now you can calculate the proportion of the free apps in each genre based on the value counts you obtained in the previous two steps.

# %% [markdown]
# Relative figures. Before we don't really get to know which are the categories with the highest concentration of free apps, because we are not considering number of apps of each category.

# %%
apps["status"] = np.where(apps.price == 0, "free", "paid")

# %%
apps_pivot = apps.groupby(["prime_genre", "status"]).id.count().to_frame().unstack()

# %%
apps_pivot.columns = apps_pivot.columns.droplevel(0)

# %%
apps_pivot.head()
# Out:
# status         free  paid  total_apps  free_proportion
# prime_genre
# Book             66    46         112         0.589286
# Business         20    37          57         0.350877
# Catalogs          9     1          10         0.900000
# Education       132   321         453         0.291391
# Entertainment   334   201         535         0.624299

# %%
apps_pivot["total_apps"] = apps_pivot.free + apps_pivot.paid

# %%
apps_pivot["free_proportion"] = apps_pivot.free / apps_pivot.total_apps

# %%
apps_pivot.sort_values(by="free_proportion", ascending=False)
# Out:
# status             free  paid  total_apps  free_proportion
# prime_genre
# Shopping            121     1         122         0.991803
# Catalogs              9     1          10         0.900000
# Social Networking   143    24         167         0.856287
# Finance              84    20         104         0.807692
# News                 58    17          75         0.773333
# Sports               79    35         114         0.692982
# Travel               56    25          81         0.691358
# Food & Drink         43    20          63         0.682540
# Lifestyle            94    50         144         0.652778
# Entertainment       334   201         535         0.624299
# Book                 66    46         112         0.589286
# Games              2257  1605        3862         0.584412
# Music                67    71         138         0.485507
# Photo & Video       167   182         349         0.478510
# Utilities           109   139         248         0.439516
# Navigation           20    26          46         0.434783
# Weather              31    41          72         0.430556
# Health & Fitness     76   104         180         0.422222
# Business             20    37          57         0.350877
# Productivity         62   116         178         0.348315
# Medical               8    15          23         0.347826
# Reference            20    44          64         0.312500
# Education           132   321         453         0.291391

# %% [markdown]
# ### If a developer tries to make money by developing and selling Apple Store apps, in which genre should s/he develop the apps? Please assume all apps cost the same amount of time and expense to develop.

# %%
apps_summary=apps.groupby("prime_genre")\
            .agg({"id":"count","price":"mean", "rating_count_tot":"sum", "user_rating":"mean"})

# %%
apps_summary["user_response"] = apps_summary.rating_count_tot / apps_summary.id

# %%
apps_summary["profit_proxy"] = apps_summary.user_response * apps_summary.price

# %%
apps_summary.sort_values(by="profit_proxy", ascending=False)
# Out:
#                      id     price  rating_count_tot  user_rating  \
# prime_genre
# Music               138  4.835435           3980199     3.978261
# Reference            64  4.836875           1434294     3.453125
# Navigation           46  4.124783            545282     2.684783
# Weather              72  1.605417           1597034     3.597222
# Productivity        178  4.330562           1433136     4.005618
# Business             57  5.116316            272921     3.745614
# Food & Drink         63  1.552381            878133     3.182540
# Photo & Video       349  1.473295           5008946     3.800860
# Games              3862  1.432923          52878491     3.685008
# Health & Fitness    180  1.916444           1784371     3.700000
# Travel               81  1.120370           1144485     3.376543
# Social Networking   167  0.339880           7598316     2.985030
# Sports              114  0.953070           1599070     2.982456
# Utilities           248  1.647621           1702228     3.278226
# Book                112  1.790536            574049     2.477679
# Education           453  4.028234           1014371     3.376380
# News                 75  0.517733            976130     2.980000
# Entertainment       535  0.889701           4030518     3.246729
# Lifestyle           144  0.885417            887294     2.805556
# Medical              23  8.776087             13634     3.369565
# Finance             104  0.421154           1148956     2.432692
# Catalogs             10  0.799000             17325     2.100000
# Shopping            122  0.016311           2271070     3.540984
#
#                    user_response   profit_proxy
# prime_genre
# Music               28842.021739  139463.715118
# Reference           22410.843750  108398.449863
# Navigation          11853.956522   48894.993705
# Weather             22181.027778   35609.791678
# Productivity         8051.325843   34866.764116
# Business             4788.087719   24497.368800
# Food & Drink        13938.619048   21638.046712
# Photo & Video       14352.280802   21145.145395
# Games               13691.996634   19619.581764
# Health & Fitness     9913.172222   18998.043832
# Travel              14129.444444   15830.210905
# Social Networking   45498.898204   15464.176419
# Sports              14026.929825   13368.648469
# Utilities            6863.822581   11308.978003
# Book                 5125.437500    9177.278895
# Education            2239.229581    9020.140720
# News                13015.066667    6738.333849
# Entertainment        7533.678505    6702.720806
# Lifestyle            6161.763889    5455.728443
# Medical               592.782609    5202.311720
# Finance             11047.653846    4652.761908
# Catalogs             1732.500000    1384.267500
# Shopping            18615.327869     303.643463

# %%
apps_summary["user_rating_adjustment_factor"] = apps_summary.user_rating \
                                                .apply(lambda x: 1/(x/apps_summary.user_rating.min()))

# %%
apps_summary["profit_proxy_adjusted"] = apps_summary.profit_proxy * apps_summary.user_rating_adjustment_factor

# %%
apps_summary.sort_values(by="profit_proxy_adjusted", ascending=False)
# Out:
#                      id     price  rating_count_tot  user_rating  \
# prime_genre
# Music               138  4.835435           3980199     3.978261
